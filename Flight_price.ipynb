# %%
print("Shree")
# Out:
# Shree

# %%
# !pip install pyforest
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pyforest

# %%
df=pd.read_csv("Desktop/archive/Clean_Dataset.csv")

# %%
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df=df.drop(columns=["Unnamed: 0","flight","departure_time","arrival_time"])

# %%
df
# Out:
#          airline source_city stops destination_city     class  duration  \
# 0       SpiceJet       Delhi  zero           Mumbai   Economy      2.17
# 1       SpiceJet       Delhi  zero           Mumbai   Economy      2.33
# 2        AirAsia       Delhi  zero           Mumbai   Economy      2.17
# 3        Vistara       Delhi  zero           Mumbai   Economy      2.25
# 4        Vistara       Delhi  zero           Mumbai   Economy      2.33
# ...          ...         ...   ...              ...       ...       ...
# 300148   Vistara     Chennai   one        Hyderabad  Business     10.08
# 300149   Vistara     Chennai   one        Hyderabad  Business     10.42
# 300150   Vistara     Chennai   one        Hyderabad  Business     13.83
# 300151   Vistara     Chennai   one        Hyderabad  Business     10.00
# 300152   Vistara     Chennai   one        Hyderabad  Business     10.08
#
#         days_left  price
# 0               1   5953
# 1               1   5953
# ...

# %%
Y=df.price

# %%
X=df.drop(columns=["price"],axis=1)

# %%
X
# Out:
#          airline source_city stops destination_city     class  duration  \
# 0       SpiceJet       Delhi  zero           Mumbai   Economy      2.17
# 1       SpiceJet       Delhi  zero           Mumbai   Economy      2.33
# 2        AirAsia       Delhi  zero           Mumbai   Economy      2.17
# 3        Vistara       Delhi  zero           Mumbai   Economy      2.25
# 4        Vistara       Delhi  zero           Mumbai   Economy      2.33
# ...          ...         ...   ...              ...       ...       ...
# 300148   Vistara     Chennai   one        Hyderabad  Business     10.08
# 300149   Vistara     Chennai   one        Hyderabad  Business     10.42
# 300150   Vistara     Chennai   one        Hyderabad  Business     13.83
# 300151   Vistara     Chennai   one        Hyderabad  Business     10.00
# 300152   Vistara     Chennai   one        Hyderabad  Business     10.08
#
#         days_left
# 0               1
# 1               1
# 2               1
# 3               1
# ...

# %%
X["stops"].value_counts()
# Out:
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %%
X["airline"].value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
X["source_city"].value_counts()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
X["destination_city"].value_counts()
# Out:
# destination_city
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: count, dtype: int64

# %%
X["class"].value_counts()
# Out:
# class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
X["airline"]=le.fit_transform(X["airline"])

# %%
list(le.inverse_transform([0,1,2,3,4,5]))
# Out:
# ['AirAsia', 'Air_India', 'GO_FIRST', 'Indigo', 'SpiceJet', 'Vistara']

# %%
X["source_city"]=le.fit_transform(X["source_city"])

# %%
list(le.inverse_transform([0,1,2,3,4,5]))
# Out:
# ['Bangalore', 'Chennai', 'Delhi', 'Hyderabad', 'Kolkata', 'Mumbai']

# %%
X["stops"]=le.fit_transform(X["stops"])

# %%
list(le.inverse_transform([0,1,2]))
# Out:
# ['one', 'two_or_more', 'zero']

# %%
X["destination_city"]=le.fit_transform(X["destination_city"])

# %%
list(le.inverse_transform([0,1,2,3,4,5]))
# Out:
# ['Bangalore', 'Chennai', 'Delhi', 'Hyderabad', 'Kolkata', 'Mumbai']

# %%
X["class"]=le.fit_transform(X["class"])

# %%
list(le.inverse_transform([0,1]))
# Out:
# ['Business', 'Economy']

# %%
X
# Out:
#         airline  source_city  stops  destination_city  class  duration  \
# 0             4            2      2                 5      1      2.17
# 1             4            2      2                 5      1      2.33
# 2             0            2      2                 5      1      2.17
# 3             5            2      2                 5      1      2.25
# 4             5            2      2                 5      1      2.33
# ...         ...          ...    ...               ...    ...       ...
# 300148        5            1      0                 3      0     10.08
# 300149        5            1      0                 3      0     10.42
# 300150        5            1      0                 3      0     13.83
# 300151        5            1      0                 3      0     10.00
# 300152        5            1      0                 3      0     10.08
#
#         days_left
# 0               1
# 1               1
# 2               1
# 3               1
# ...

# %%
X1= X.iloc[1:150000]

# %%
X2=X.iloc[150000:300000]

# %%
X1
# Out:
#         airline  source_city  stops  destination_city  class  duration  \
# 1             4            2      2                 5      1      2.33
# 2             0            2      2                 5      1      2.17
# 3             5            2      2                 5      1      2.25
# 4             5            2      2                 5      1      2.33
# 5             5            2      2                 5      1      2.33
# ...         ...          ...    ...               ...    ...       ...
# 149995        1            4      0                 1      1     13.00
# 149996        3            4      0                 1      1     11.00
# 149997        3            4      2                 1      1      2.42
# 149998        0            4      0                 1      1      3.92
# 149999        3            4      2                 1      1      2.33
#
#         days_left
# 1               1
# 2               1
# 3               1
# 4               1
# ...

# %%
X2
# Out:
#         airline  source_city  stops  destination_city  class  duration  \
# 150000        5            4      0                 1      1     15.58
# 150001        5            4      0                 1      1     26.33
# 150002        5            4      0                 1      1      9.17
# 150003        5            4      0                 1      1     13.08
# 150004        1            4      0                 1      1     22.50
# ...         ...          ...    ...               ...    ...       ...
# 299995        5            1      0                 3      0     11.17
# 299996        5            1      0                 3      0     11.33
# 299997        5            1      0                 3      0     13.92
# 299998        5            1      0                 3      0     15.75
# 299999        5            1      0                 3      0     19.33
#
#         days_left
# 150000         23
# 150001         23
# 150002         23
# 150003         23
# ...

# %%
Y1=Y.iloc[1:150000]

# %%
Y2=Y.iloc[150000:300000]

# %%
Y1
# Out:
# 1         5953
# 2         5956
# 3         5955
# 4         5955
# 5         5955
#           ...
# 149995    5324
# 149996    5437
# 149997    5465
# 149998    5465
# 149999    5570
# Name: price, Length: 149999, dtype: int64

# %%
Y2
# Out:
# 150000     5910
# 150001     5910
# 150002     6009
# 150003     6009
# 150004     5704
#           ...
# 299995    41064
# 299996    41064
# 299997    41064
# 299998    41064
# 299999    41064
# Name: price, Length: 150000, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
rf= RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_train,y_train)
# Out:
# 0.9954858423875521

# %%
import joblib
joblib.dump(rf,"Flight_fare.pkl")
# Out:
# ['Flight_fare.pkl']

# %%
X_test
# Out:
#         airline  source_city  stops  destination_city  class  duration  \
# 177446        3            3      0                 1      1      5.08
# 118901        4            0      2                 1      1      1.08
# 168086        1            3      0                 0      1     23.25
# 224450        1            2      0                 1      0     14.92
# 60102         3            5      2                 0      1      1.75
# ...         ...          ...    ...               ...    ...       ...
# 233234        5            5      0                 0      0     13.92
# 139578        5            4      0                 0      1     12.42
# 240481        5            5      0                 3      0     11.00
# 89853         2            0      0                 2      1      7.00
# 38722         5            2      0                 1      1      6.33
#
#         days_left
# 177446         16
# 118901         41
# 168086         26
# 224450         42
# ...

# %%
y_test
# Out:
# 177446     7136
# 118901     1606
# 168086     6314
# 224450    45257
# 60102      2124
#           ...
# 233234    83952
# 139578     6458
# 240481    45805
# 89853      4028
# 38722      4979
# Name: price, Length: 60031, dtype: int64
